# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("C:\\Users\\srmve\\Downloads\\age.csv")
df
# Out:
#                        name    birthday           title    character_name  \
# 0                 Ben Platt  24-09-1993  The Politician     Payton Hobart
# 1               Zoey Deutch  10-11-1994  The Politician  Infinity Jackson
# 2              Lucy Boynton  17-01-1994  The Politician      Astrid Sloan
# 3          Julia Schlaepfer  03-03-1995  The Politician     Alice Charles
# 4            Laura Dreyfuss  22-08-1988  The Politician  McAfee Westbrook
# ..                      ...         ...             ...               ...
# 238  Thomas Mitchell Barnet         NaN     Locke & Key        Sam Lesser
# 239             Kevin Alves  19-10-1991     Locke & Key              Javi
# 240          Asha Bromfield  09-11-1994     Locke & Key       Zadie Wells
# 241           Felix Mallard  20-04-1998     Locke & Key  Lucas Caravaggio
# 242            Hallea Jones         NaN     Locke & Key      Eden Hawkins
#
#     character_year  characterage character_gender  \
# 0        hs senior           NaN                M
# 1        hs senior           NaN                F
# 2        hs senior           NaN                F
# 3        hs senior           NaN                F
# 4        hs senior           NaN                F
# ..             ...           ...              ...
# 238      hs junior           NaN                M
# 239      hs junior           NaN                M
# 240      hs junior           NaN                F
# 241            NaN          17.0                M
# 242      hs junior           NaN                F
#
#                                   love_interest release_date  actor_age
# 0    Alice Charles, Astrid Sloan, River Barkley   27-09-2019       26.0
# 1                                           NaN   27-09-2019       24.0
# 2                  Payton Hobart, River Barkley   27-09-2019       25.0
# 3                 Payton Hobart, James Sullivan   27-09-2019       24.0
# 4                                 Skye Leighton   27-09-2019       31.0
# ..                                          ...          ...        ...
# 238                                         NaN   07-02-2020        NaN
# 239                                         NaN   07-02-2020       28.0
# 240                                         NaN   07-02-2020       25.0
# 241                                         NaN   07-02-2020       21.0
# 242                                         NaN   07-02-2020        NaN
#
# [243 rows x 10 columns]

# %%
df.head()
# Out:
#                name    birthday           title    character_name  \
# 0         Ben Platt  24-09-1993  The Politician     Payton Hobart
# 1       Zoey Deutch  10-11-1994  The Politician  Infinity Jackson
# 2      Lucy Boynton  17-01-1994  The Politician      Astrid Sloan
# 3  Julia Schlaepfer  03-03-1995  The Politician     Alice Charles
# 4    Laura Dreyfuss  22-08-1988  The Politician  McAfee Westbrook
#
#   character_year  characterage character_gender  \
# 0      hs senior           NaN                M
# 1      hs senior           NaN                F
# 2      hs senior           NaN                F
# 3      hs senior           NaN                F
# 4      hs senior           NaN                F
#
#                                 love_interest release_date  actor_age
# 0  Alice Charles, Astrid Sloan, River Barkley   27-09-2019       26.0
# 1                                         NaN   27-09-2019       24.0
# 2                Payton Hobart, River Barkley   27-09-2019       25.0
# 3               Payton Hobart, James Sullivan   27-09-2019       24.0
# 4                               Skye Leighton   27-09-2019       31.0

# %%
df.isnull().sum()
# Out:
# name                  0
# birthday             16
# title                 0
# character_name        0
# character_year      132
# characterage        112
# character_gender      0
# love_interest       111
# release_date          0
# actor_age            16
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              243 non-null    object
#  1   birthday          227 non-null    object
#  2   title             243 non-null    object
#  3   character_name    243 non-null    object
#  4   character_year    111 non-null    object
#  5   characterage      131 non-null    float64
#  6   character_gender  243 non-null    object
#  7   love_interest     132 non-null    object
#  8   release_date      243 non-null    object
#  9   actor_age         227 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 19.1+ KB

# %%
df.describe()
# Out:
#        characterage   actor_age
# count    131.000000  227.000000
# mean      16.580153   21.977974
# std        1.518877    3.908743
# min       10.000000   11.000000
# 25%       16.000000   20.000000
# 50%       17.000000   22.000000
# 75%       17.000000   24.000000
# max       25.000000   32.000000

# %%
df['birthday']=pd.to_datetime(df['birthday'])
df['birthday']
# Out:
# 0     1993-09-24
# 1     1994-11-10
# 2     1994-01-17
# 3     1995-03-03
# 4     1988-08-22
#          ...
# 238          NaT
# 239   1991-10-19
# 240   1994-11-09
# 241   1998-04-20
# 242          NaT
# Name: birthday, Length: 243, dtype: datetime64[ns]

# %%
df['birth_year']=df['birthday'].dt.year
df['birth_year']
# Out:
# 0      1993.0
# 1      1994.0
# 2      1994.0
# 3      1995.0
# 4      1988.0
#         ...
# 238       NaN
# 239    1991.0
# 240    1994.0
# 241    1998.0
# 242       NaN
# Name: birth_year, Length: 243, dtype: float64

# %%
df['birth_year'].isnull().sum()
# Out:
# 16

# %%
df = df. drop (['birthday', 'title','character_name', 'character_year', 'characterage', 'love_interest', 'release_date'],
axis=1)
df
# Out:
#                        name character_gender  actor_age  birth_year
# 0                 Ben Platt                M       26.0      1993.0
# 1               Zoey Deutch                F       24.0      1994.0
# 2              Lucy Boynton                F       25.0      1994.0
# 3          Julia Schlaepfer                F       24.0      1995.0
# 4            Laura Dreyfuss                F       31.0      1988.0
# ..                      ...              ...        ...         ...
# 238  Thomas Mitchell Barnet                M        NaN         NaN
# 239             Kevin Alves                M       28.0      1991.0
# 240          Asha Bromfield                F       25.0      1994.0
# 241           Felix Mallard                M       21.0      1998.0
# 242            Hallea Jones                F        NaN         NaN
#
# [243 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
categorical_columns=['name','character_gender']
df[categorical_columns]=df[categorical_columns].apply(label_encoder.fit_transform)
df[categorical_columns]
# Out:
#      name  character_gender
# 0      24                 1
# 1     239                 0
# 2     151                 0
# 3     126                 0
# 4     142                 0
# ..    ...               ...
# 238   229                 1
# 239   135                 1
# 240    18                 0
# 241    80                 1
# 242    94                 0
#
# [243 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# name                 0
# character_gender     0
# actor_age           16
# birth_year          16
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
numeric_columns=['birth_year','actor_age']
df[numeric_columns]=SimpleImputer(strategy='most_frequent').fit_transform(df[numeric_columns])
df[numeric_columns]
# Out:
#      birth_year  actor_age
# 0        1993.0       26.0
# 1        1994.0       24.0
# 2        1994.0       25.0
# 3        1995.0       24.0
# 4        1988.0       31.0
# ..          ...        ...
# 238      1996.0       22.0
# 239      1991.0       28.0
# 240      1994.0       25.0
# 241      1998.0       21.0
# 242      1996.0       22.0
#
# [243 rows x 2 columns]

# %%
x = df[['name', 'character_gender', 'birth_year']]
x
# Out:
#      name  character_gender  birth_year
# 0      24                 1      1993.0
# 1     239                 0      1994.0
# 2     151                 0      1994.0
# 3     126                 0      1995.0
# 4     142                 0      1988.0
# ..    ...               ...         ...
# 238   229                 1      1996.0
# 239   135                 1      1991.0
# 240    18                 0      1994.0
# 241    80                 1      1998.0
# 242    94                 0      1996.0
#
# [243 rows x 3 columns]

# %%
y=df['actor_age']
y
# Out:
# 0      26.0
# 1      24.0
# 2      25.0
# 3      24.0
# 4      31.0
#        ...
# 238    22.0
# 239    28.0
# 240    25.0
# 241    21.0
# 242    22.0
# Name: actor_age, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([20.96896576, 20.48189031, 23.98791426, 22.9970159 , 19.8965741 ,
#        17.28510815, 22.77228179, 21.71283275, 19.21921396, 20.88320471,
#        21.36084351, 22.63094137, 23.87988464, 21.70734032, 21.96965298,
#        22.59961703, 22.36275541, 23.98011186, 21.75590371, 20.4149452 ,
#        19.9650674 , 21.33539249, 22.44693957, 20.95365579, 19.48155529,
#        19.28189132, 23.30082263, 21.13143208, 21.67370601, 21.4567743 ,
#        21.11185437, 20.66358214, 20.75948424, 20.81272495, 20.96110599,
#        23.87634999, 25.67735604, 21.50571858, 21.91445449, 25.56342443,
#        20.95131713, 20.74577984, 20.03516628, 18.88606934, 20.97676816,
#        20.87928917, 23.72916495, 21.7092981 , 24.51648379])

# %%
from sklearn. metrics import mean_squared_error
mse = mean_squared_error (y_test, y_pred)
print (f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 7.939242222167703

# %%
new_data = pd. DataFrame ({"name": [142], "character_gender": [1], "birth_year": [1996.0]})
predicted_age = model. predict(new_data)
print (f"Predicted Actor Age: {predicted_age [0]}")
# Out:
# Predicted Actor Age: 21.188207442392354

# %%
new_data = pd. DataFrame ({"name": [12], "character_gender": [1], "birth_year": [1998.0]})
predicted_age = model. predict(new_data)
print (f"Predicted Actor Age: {predicted_age [0]}")
# Out:
# Predicted Actor Age: 20.29552115728484
